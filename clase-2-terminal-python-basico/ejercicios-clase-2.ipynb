# %%
print("hello world")
# Out:
# hello world

# %%
2+2
# Out:
# 4

# %%
a = 2

# %%
a
# Out:
# 2

# %%
a + 2
# Out:
# 4

# %%
numerica = 25

# %%
texto = "soy un texto"

# %%
numerica
# Out:
# 25

# %%
texto
# Out:
# 'soy un texto'

# %%
nombre = "Jonathan"

# %%
nombre
# Out:
# 'Jonathan'

# %%
def suma():
  resultado = 2+2
  print(resultado)

# %%
suma()
# Out:
# 4
