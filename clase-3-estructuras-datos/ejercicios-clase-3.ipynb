# %%
# Variables / datos atómicos en python (int, float, str, bool)
entero = 15
flotante = 15.3
cadena = "texto"
booleano = True

# %%
type(booleano)
# Out:
# bool

# %%
#Más ejercicios con variables
suma = entero + flotante
print(suma)
print(cadena)
# Out:
# 30.3
# texto

# %%
# Lista en python

nombres = ["Noemi", "Jonathan", "Melissa","Edgar"]
numeros = [1,2,3,4,5,6,7]
combi = ["hola",12, [1,2]]
print(nombres)
# Out:
# ['Noemi', 'Jonathan', 'Melissa', 'Edgar']

# %%
# Vamos a hablar de gatitos
nombre = "Panchito"
edad = 4
personalidad = "jugueton"

# %%
def gatite(name, age, style):
  print("Le gatite ", name, "tiene ", age, "años y su personalidad es ", style)

# %%
gatite(nombre,edad,personalidad)
gatite("polo",7,"cariñoso")
# Out:
# Le gatite  Panchito tiene  4 años y su personalidad es  jugueton
# Le gatite  polo tiene  7 años y su personalidad es  cariñoso

# %% [markdown]
# # Estructura condicional if, elif, else (Decisiones)
#
# ## Lógica:
# "Si pasa algo -> haz esto. Si no haz otra cosa"
#
# " > mayor que, < menor que, <= menor que o igual, >= mayor que o igual, == igual, != diferente"

# %%
edad = 18

if edad >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres mayor de edad

# %%
if edad >= 18:
    print("Eres mayor de edad")
    años_para_cumplir_21 = 21-edad
    print("Te faltan ", años_para_cumplir_21, "años para cumplir 21 años")
else:
    print("Eres menor de edad")
    años_para_cumplir_21 = 21-edad
    print("Te faltan ", años_para_cumplir_21, "años para cumplir 21 años")
# Out:
# Eres mayor de edad
# Te faltan  3 años para cumplir 21 años

# %%
hora_de_comida = 3
contacto = 4
contacto2 = 3

# Tengo una regla de que si alguien necesita apoyo en mi hora de comida no puedo, todas las demás horas si.

if contacto != hora_de_comida:
    print(" Si te puedo atender")
else: 
    print("No te puedo atender")
# Out:
#  Si te puedo atender

# %%
if contacto2 != hora_de_comida:
    print(" Si te puedo atender")
else: 
    print("No te puedo atender")
# Out:
# No te puedo atender

# %% [markdown]
# ## Ejercicio

# %%
# input me permite obtener respuestas o interacción, el script se pausa esperando una respuesta, y siempre esa respuesta será 
# una cadena de texto (str), si quiero cambiarle el tipo pongo int para entero, antes.
edad = int(input("Cuantos años tienes:"))

if edad >= 18:
    print("Puedes aprender ciencia de datos sin permiso de tus papás")
else:
    print("Que chido que empieces joven")
# Out:
# Cuantos años tienes: 36
# Puedes aprender ciencia de datos sin permiso de tus papás

# %% [markdown]
# # Estructura de repetición for (Ciclo controlado)
#
# ## Lógica:
# "Repite esta acción una cantidad determinada de veces"

# %%
for i in range(3,7):
    print("Hola ", i)
# Out:
# Hola  3
# Hola  4
# Hola  5
# Hola  6

# %%
for i in nombres:
    print(i)
# Out:
# Noemi
# Jonathan
# Melissa
# Edgar

# %% [markdown]
# ## Ejercicio

# %%
lenguajes = ["Python", "R", "SQL", "Julia", "Scala"]

for lenguaje in lenguajes:
    print("Uno de los lenguajes más usados es:", lenguaje)
# Out:
# Uno de los lenguajes más usados es: Python
# Uno de los lenguajes más usados es: R
# Uno de los lenguajes más usados es: SQL
# Uno de los lenguajes más usados es: Julia
# Uno de los lenguajes más usados es: Scala

# %% [markdown]
# # Estructura de repetición while (Ciclo condicionado)
#
# ## Lógica:
# "Repite algo mientras se cumple una condición"

# %%
x = 0

while x < 5:
    print(x)
    #x = x+1
    x += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
dias = 0

while dias < 3:
    print("Estudia un poco más, Día ", dias + 1)
    dias += 1

print ("Bien hecho has estdiado al menos 3 días esta semana")
# Out:
# Estudia un poco más, Día  1
# Estudia un poco más, Día  2
# Estudia un poco más, Día  3
# Bien hecho has estdiado al menos 3 días esta semana

# %% [markdown]
# # Cadenas de texto

# %%
texto = "Hola mundo"

# %%
type(texto)
# Out:
# str

# %%
texto.upper()
# Out:
# 'HOLA MUNDO'

# %%
texto.lower()
# Out:
# 'hola mundo'

# %%
texto.replace("Hola", "Hellooow")
# Out:
# 'Hellooow mundo'

# %%
len(texto)
# Out:
# 10

# %%
texto[0]
# Out:
# 'H'

# %%
texto[4]
# Out:
# ' '

# %%
texto[0:4]
# Out:
# 'Hola'

# %%
texto[-1]
# Out:
# 'o'

# %%
texto[-2]
# Out:
# 'd'

# %%
texto[9]
# Out:
# 'o'

# %%
texto[5:]
# Out:
# 'mundo'

# %%
texto[:5]
# Out:
# 'Hola '

# %%
texto[5:] + texto[:5]
# Out:
# 'mundoHola '

# %% [markdown]
# # Listas

# %%
mi_lista = [1,2,3,"Python",True]

# %%
mi_lista[0]
# Out:
# 1

# %%
mi_lista[-1]
# Out:
# True

# %%
mi_lista.append(5) # me sirve para agregar elementos al final de la lista

# %%
mi_lista.append("seis")

# %%
mi_lista
# Out:
# [1, 2, 3, 'Python', True, 5, 'seis']

# %%
mi_lista.insert(3,4) # insert me agrega el elemento en la posición indicada primero va la posición y luego el elemento a agregar

# %%
mi_lista
# Out:
# [1, 2, 3, 4, 'Python', True, 5, 'seis']

# %%
mi_lista.remove(4) # quita el primer elmento que haga match con el valor que le indique

# %%
mi_lista
# Out:
# [1, 2, 3, 'Python', True, 5, 'seis']

# %%
mi_lista.insert(5,5)

# %%
mi_lista
# Out:
# [1, 2, 3, 'Python', True, 5, 5, 'seis']

# %%
mi_lista.remove(5)

# %%
mi_lista
# Out:
# ['Python', 5]

# %%
mi_lista = [5, 3, 8, 2]
print("Lista original:", mi_lista)

for i in range(1,5):
    if i in mi_lista:
        mi_lista.remove(i)
        print(f"✅ Eliminado {i}: {mi_lista}")
    else:
        print(f"❌ {i} no está en la lista")

print("Lista final:", mi_lista)
# Out:
# Lista original: [5, 3, 8, 2]
# ❌ 1 no está en la lista
# ✅ Eliminado 2: [5, 3, 8]
# ✅ Eliminado 3: [5, 8]
# ❌ 4 no está en la lista
# Lista final: [5, 8]

# %%
mi_lista.pop() #Elimina el último elemento
# Out:
# 8

# %%
mi_lista
# Out:
# [5]

# %%
mi_lista.sort()

# %%
numeros = [7,5,1,4,3]

# %%
numeros.sort() # Ordena listas que tengan valores todos del mismo tipo

# %%
numeros
# Out:
# [1, 3, 4, 5, 7]

# %%
numeros.reverse() # Invierte el orden

# %%
numeros
# Out:
# [7, 5, 4, 3, 1]

# %%
mi_lista.append(5)

# %%
mi_lista
# Out:
# [5, 5]

# %%
mi_lista.count(5) #Cuenta las veces que se repite un valor en la lista
# Out:
# 2

# %%
len(mi_lista) #para saber la longitud de mi lista
# Out:
# 2

# %%
mi_lista.append([2,3])

# %%
mi_lista
# Out:
# [5, 5, [2, 3]]

# %%
mi_lista[1]
# Out:
# 5

# %%
mi_lista[2][0]
# Out:
# 2

# %%
mi_lista[2][1]
# Out:
# 3

# %% [markdown]
# # Tuplas

# %%
mi_tupla = (1,2,3,"Python")

# %%
mi_tupla[2]
# Out:
# 3

# %%
mi_tupla.count(3)
# Out:
# 1

# %%
mi_tupla.index("Python")
# Out:
# 3

# %%
list(mi_tupla)
# Out:
# [1, 2, 3, 'Python']

# %%
tuple(mi_lista)
# Out:
# (5, 5, [2, 3])

# %% [markdown]
# # Diccionarios

# %%
mi_dict = {"nombre":"Python", "version":3.12, "activo":True}

# %%
mi_dict
# Out:
# {'nombre': 'Python', 'version': 3.12, 'activo': True}

# %%
mi_dict["nombre"]
# Out:
# 'Python'

# %%
mi_dict["version"]
# Out:
# 3.12

# %%
mi_dict["activo"]
# Out:
# True

# %%
mi_dict["año"] = 2024

# %%
mi_dict
# Out:
# {'nombre': 'Python', 'version': 3.12, 'activo': True, 'año': 2024}

# %%
mi_dict.keys()
# Out:
# dict_keys(['nombre', 'version', 'activo', 'año'])

# %%
for key in mi_dict.keys():
    print(key)
# Out:
# nombre
# version
# activo
# año

# %%
mi_dict.values()
# Out:
# dict_values(['Python', 3.12, True, 2024])

# %%
for value in mi_dict.values():
    print(value)
# Out:
# Python
# 3.12
# True
# 2024

# %%
mi_dict.items()
# Out:
# dict_items([('nombre', 'Python'), ('version', 3.12), ('activo', True), ('año', 2024)])

# %%
for key,value in mi_dict.items():
    print(key, ":", value)
# Out:
# nombre : Python
# version : 3.12
# activo : True
# año : 2024

# %%
mi_dict.pop("activo")
# Out:
# True

# %%
mi_dict
# Out:
# {'nombre': 'Python', 'version': 3.12, 'año': 2024}

# %%
mi_dict.clear()

# %%
mi_dict
# Out:
# {}

# %%
dicton = {}

# %%
dicton
# Out:
# {}

# %%
lista = []

# %%
lista
# Out:
# []

# %%
materias = {}

# %%
materias["Lunes"]= [6103, 7540]
materias["Martes"]= [6201]
materias["Miércoles"]= [6103, 7540]
materias["Jueves"]= []
materias["Viernes"]= [6201]

# %%
materias
# Out:
# {'Lunes': [6103, 7540],
#  'Martes': [6201],
#  'Miércoles': [6103, 7540],
#  'Jueves': [],
#  'Viernes': [6201]}

# %%
materias["Viernes"]
# Out:
# [6201]

# %%
#get me sirve para revisar si tengo una clave dentro de mi dict, sin que me de error,
# el primer parametro es la clave y el segundo un mensaje si no la encuentra esa clave
materias.get("domingo", "no existe")
# Out:
# 'no existe'

# %%
materias.get("Lunes")
# Out:
# [6103, 7540]

# %%
import numpy

# %% [markdown]
# # Funciones
#
# - "def": palabra reservada para definiri una función
# - saludar: nombre de la función
# - (): donde puedo indicar los datos de entrada o parametros
# - ":" : indican que lo que sigue es el bloque de la función
# - El código dentro de mi función está identado

# %%
def saludar():
    print("Hola, bienvenida al mundo de la ciencia de datos")

# %%
saludar()
# Out:
# Hola, bienvenida al mundo de la ciencia de datos

# %%
# funciones con parametros
name = "Edgar"

def saludar_persona(nombre):
    print("Hola ", nombre, "bienvenida al curso")

saludar_persona("Haydé")
saludar_persona("Jonathan")
saludar_persona(name)
# Out:
# Hola  Haydé bienvenida al curso
# Hola  Jonathan bienvenida al curso
# Hola  Edgar bienvenida al curso

# %%
# funciones con input

def saludar_input():
    nombre = input("Cual es tu nombre?")
    print("Hola ", nombre)

# %%
# Return

def sumar(a,b):
    resultado = a + b
    return resultado
    hola = 123
    print(hola)

# %%
sumar(1,2)
# Out:
# 3
